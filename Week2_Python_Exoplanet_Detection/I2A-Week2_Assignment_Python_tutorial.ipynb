# %%
#Installing modules. 
# !pip install numpy
# !pip install matplotlib
# !pip install astropy
# !pip install pandas
# Out:
# Requirement already satisfied: numpy in c:\users\tshel\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.3.2)
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\tshel\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\tshel\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tshel\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\tshel\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tshel\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tshel\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\tshel\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\tshel\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\tshel\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tshel\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tshel\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\tshel\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\tshel\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: astropy in c:\users\tshel\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (7.1.0)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\tshel\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from astropy) (2.3.2)
# Requirement already satisfied: pyerfa>=2.0.1.1 in c:\users\tshel\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from astropy) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.4.28.0.37.27 in c:\users\tshel\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from astropy) (0.2025.8.4.0.42.59)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\tshel\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from astropy) (6.0.2)
# Requirement already satisfied: packaging>=22.0.0 in c:\users\tshel\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from astropy) (25.0)
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\tshel\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
#importing 
import numpy as np
import matplotlib.pyplot as plt
import astropy.io
import pandas as pd

# %%
# printing Hello World
print('Hello World')
# creating variables a and b, then printing the ouput of a*b
a,b = 3,4
print('Product of a and b is ',a*b)
# Out:
# Hello World
# Product of a and b is  12

# %%
np.loadtxt(fname='inflammation-01.csv', delimiter=',')
# Out:
# array([[0., 0., 1., 0., 0.],
#        [0., 2., 4., 2., 0.],
#        [2., 4., 6., 4., 2.],
#        [0., 2., 4., 2., 0.],
#        [0., 0., 1., 0., 0.]])

# %%
data = np.loadtxt(fname='inflammation-01.csv', delimiter=',')

# %%
print(data)
# Out:
# [[0. 0. 1. 0. 0.]
#  [0. 2. 4. 2. 0.]
#  [2. 4. 6. 4. 2.]
#  [0. 2. 4. 2. 0.]
#  [0. 0. 1. 0. 0.]]

# %%
print(type(data))
# Out:
# <class 'numpy.ndarray'>

# %%
import time
print(time.ctime())
# Out:
# Sun Aug 10 11:59:08 2025

# %%
import matplotlib.pyplot
image = matplotlib.pyplot.imshow(data)
matplotlib.pyplot.show()

# %%
#Using numpy and matplotlib 
'''
Creates a quadratic function to find b
uses matplotlilb to plot each values of a to b 
-k  is the colour(black) and the style of the line
show displays a graph
'''
a = np.linspace(-100,100,1000) #to create an array of evenly spaced 1000 numbers from -100 to 100 
b = 2*a**2 + 5
plt.plot(a,b,'-k')
plt.show()

# %%
# Saving the plot as img 
plt.savefig("my_plot.png")

# %%
#loading the image
#Copy path and change it to load
from astropy.io import fits
file_dir = "C:/Users/Tshewang Phuntsho/Desktop/test_data/"
img_name = 'pdi_pi_collapsed.fits'
img = fits.getdata(file_dir+img_name,ext=0)

# %%
# Display the img
img_corrected = np.transpose(img, (1, 2, 0))  # change [c,h,w] to [h,w,c]
plt.imshow(img_corrected, origin='lower', vmin=-0.001, vmax=0.01)
plt.colorbar()
plt.show()

# %%
import numpy
data = numpy.loadtxt(fname='inflammation-01.csv', delimiter=',')
import matplotlib.pyplot
fig = matplotlib.pyplot.figure(figsize=(10.0,3.0))
axes1 = fig.add_subplot(1,3,1)
axes2 = fig.add_subplot(1,3,2)
axes3 = fig.add_subplot(1,3,3)

axes1.set_ylabel('average')
axes1.set_xlabel('No. of Days')
axes1.plot(numpy.mean(data, axis=0), drawstyle='steps-mid')
axes2.set_ylabel('max')
axes2.plot(numpy.amax(data, axis=0), drawstyle='steps-mid')
axes3.set_ylabel('min')
axes3.plot(numpy.amin(data, axis=0), drawstyle='steps-mid')

fig.tight_layout()

matplotlib.pyplot.savefig('inflammation.png')
matplotlib.pyplot.show()
